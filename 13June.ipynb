# %%
url = ("https://raw.githubusercontent.com/pandas-dev" "/pandas/main/pandas/tests/io/data/csv/tips.csv")

# %%
import pandas as pd
tips = pd.read_csv(url)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["total_bill"] = tips["total_bill"] - 2

# %%
#tips["total_bill"]-2
tips["total_bill"]/2
tips["total_bill"]*78
# Out:
# 0      1169.22
# 1       650.52
# 2      1482.78
# 3      1691.04
# 4      1762.02
#         ...
# 239    2108.34
# 240    1964.04
# 241    1612.26
# 242    1233.96
# 243    1308.84
# Name: total_bill, Length: 244, dtype: float64

# %%
tips["tip"]*5
# Out:
# 0       5.05
# 1       8.30
# 2      17.50
# 3      16.55
# 4      18.05
#        ...
# 239    29.60
# 240    10.00
# 241    10.00
# 242     8.75
# 243    15.00
# Name: tip, Length: 244, dtype: float64

# %%
(tips["tip"]+tips["total_bill"])-3
# Out:
# 0      13.00
# 1       7.00
# 2      19.51
# 3      21.99
# 4      23.20
#        ...
# 239    29.95
# 240    24.18
# 241    19.67
# 242    14.57
# 243    16.78
# Length: 244, dtype: float64

# %%
tips["time"]*2
# Out:
# 0      DinnerDinner
# 1      DinnerDinner
# 2      DinnerDinner
# 3      DinnerDinner
# 4      DinnerDinner
#            ...
# 239    DinnerDinner
# 240    DinnerDinner
# 241    DinnerDinner
# 242    DinnerDinner
# 243    DinnerDinner
# Name: time, Length: 244, dtype: object

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       14.99  1.01  Female     No  Sun  Dinner     2
# 1        8.34  1.66    Male     No  Sun  Dinner     3
# 2       19.01  3.50    Male     No  Sun  Dinner     3
# 3       21.68  3.31    Male     No  Sun  Dinner     2
# 4       22.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["new_bill"] = tips["total_bill"]/2
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390
#
# [244 rows x 8 columns]

# %%
tips.copy()
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390
#
# [244 rows x 8 columns]

# %%
tips["new_size"] = tips["size"]*2
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
# [244 rows x 9 columns]

# %%
tips["total_bill"] < 10
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
tips[tips["total_bill"] < 10]
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 6          6.77  2.00    Male     No   Sun  Dinner     2     3.385         4
# 10         8.27  1.71    Male     No   Sun  Dinner     2     4.135         4
# 16         8.33  1.67  Female     No   Sun  Dinner     3     4.165         6
# 30         7.55  1.45    Male     No   Sat  Dinner     2     3.775         4
# 43         7.68  1.32    Male     No   Sun  Dinner     2     3.840         4
# 51         8.29  2.60  Female     No   Sun  Dinner     2     4.145         4
# 53         7.94  1.56    Male     No   Sun  Dinner     2     3.970         4
# 58         9.24  1.76    Male    Yes   Sat  Dinner     2     4.620         4
# 62         9.02  1.98    Male    Yes   Sat  Dinner     2     4.510         4
# 67         1.07  1.00  Female    Yes   Sat  Dinner     1     0.535         2
# ...

# %%
tips.shape
# Out:
# (244, 9)

# %%
is_dinner = tips["time"] == "Dinner"

# %%
is_dinner.shape
# Out:
# (244,)

# %%
is_dinner.value_counts()
# Out:
# time
# True     176
# False     68
# Name: count, dtype: int64

# %%
is_dinner.sum()
# Out:
# 176

# %%
tips[is_dinner]
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
# [176 rows x 9 columns]

# %%
import numpy as np
tips["bucket"] = np.where(tips["total_bill"] < 10, "low", "high")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size  \
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
#     bucket
# 0     high
# 1      low
# ...

# %%
tips["bucket"].value_counts()
# Out:
# bucket
# high    204
# low      40
# Name: count, dtype: int64

# %%
tips["date1"] = pd.Timestamp("2013-01-15")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size  \
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
#     bucket      date1
# ...

# %%
tips["date2"] = pd.Timestamp("2015-02-15")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size  \
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
#     bucket      date1      date2
# ...

# %%
tips["date2_year"] = tips["date2"].dt.year

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size  \
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
#     bucket      date1      date2  date2_year
# ...

# %%
tips["months_between"] = tips["date2"].dt.to_period("M") - tips[
    "date1"].dt.to_period("M")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size  \
# 0         14.99  1.01  Female     No   Sun  Dinner     2     7.495         4
# 1          8.34  1.66    Male     No   Sun  Dinner     3     4.170         6
# 2         19.01  3.50    Male     No   Sun  Dinner     3     9.505         6
# 3         21.68  3.31    Male     No   Sun  Dinner     2    10.840         4
# 4         22.59  3.61  Female     No   Sun  Dinner     4    11.295         8
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       27.03  5.92    Male     No   Sat  Dinner     3    13.515         6
# 240       25.18  2.00  Female    Yes   Sat  Dinner     2    12.590         4
# 241       20.67  2.00    Male    Yes   Sat  Dinner     2    10.335         4
# 242       15.82  1.75    Male     No   Sat  Dinner     2     7.910         4
# 243       16.78  3.00  Female     No  Thur  Dinner     2     8.390         4
#
# ...

# %%
tips[
    ["date1", "date2","months_between"]
]
# Out:
#          date1      date2    months_between
# 0   2013-01-15 2015-02-15  <25 * MonthEnds>
# 1   2013-01-15 2015-02-15  <25 * MonthEnds>
# 2   2013-01-15 2015-02-15  <25 * MonthEnds>
# 3   2013-01-15 2015-02-15  <25 * MonthEnds>
# 4   2013-01-15 2015-02-15  <25 * MonthEnds>
# ..         ...        ...               ...
# 239 2013-01-15 2015-02-15  <25 * MonthEnds>
# 240 2013-01-15 2015-02-15  <25 * MonthEnds>
# 241 2013-01-15 2015-02-15  <25 * MonthEnds>
# 242 2013-01-15 2015-02-15  <25 * MonthEnds>
# 243 2013-01-15 2015-02-15  <25 * MonthEnds>
#
# [244 rows x 3 columns]

# %%
tips.drop("sex", axis=1)

# %%
tips

# %%
tips.rename(columns={"total_bill":"total_bill_2"})
# Out:
#      total_bill_2   tip     sex smoker   day    time  size  new_bill  \
# 0           14.99  1.01  Female     No   Sun  Dinner     2     7.495
# 1            8.34  1.66    Male     No   Sun  Dinner     3     4.170
# 2           19.01  3.50    Male     No   Sun  Dinner     3     9.505
# 3           21.68  3.31    Male     No   Sun  Dinner     2    10.840
# 4           22.59  3.61  Female     No   Sun  Dinner     4    11.295
# ..            ...   ...     ...    ...   ...     ...   ...       ...
# 239         27.03  5.92    Male     No   Sat  Dinner     3    13.515
# 240         25.18  2.00  Female    Yes   Sat  Dinner     2    12.590
# 241         20.67  2.00    Male    Yes   Sat  Dinner     2    10.335
# 242         15.82  1.75    Male     No   Sat  Dinner     2     7.910
# 243         16.78  3.00  Female     No  Thur  Dinner     2     8.390
#
#      new_size bucket      date1      date2  date2_year    months_between
# ...

# %%
tips = tips.sort_values(["total_bill"])

# %%
tips
# Out:
#      total_bill    tip     sex smoker   day    time  size  new_bill  new_size  \
# 67         1.07   1.00  Female    Yes   Sat  Dinner     1     0.535         2
# 92         3.75   1.00  Female    Yes   Fri  Dinner     2     1.875         4
# 111        5.25   1.00  Female     No   Sat  Dinner     1     2.625         2
# 172        5.25   5.15    Male    Yes   Sun  Dinner     2     2.625         4
# 149        5.51   2.00    Male     No  Thur   Lunch     2     2.755         4
# ..          ...    ...     ...    ...   ...     ...   ...       ...       ...
# 182       43.35   3.50    Male    Yes   Sun  Dinner     3    21.675         6
# 156       46.17   5.00    Male     No   Sun  Dinner     6    23.085        12
# 59        46.27   6.73    Male     No   Sat  Dinner     4    23.135         8
# 212       46.33   9.00    Male     No   Sat  Dinner     4    23.165         8
# 170       48.81  10.00    Male    Yes   Sat  Dinner     3    24.405         6
#
# ...

# %%
tips["time"].str.len()
# Out:
# 67     6
# 92     6
# 111    6
# 172    6
# 149    5
#       ..
# 182    6
# 156    6
# 59     6
# 212    6
# 170    6
# Name: time, Length: 244, dtype: int64

# %%
tips["time"].str.rstrip().str.len()
# Out:
# 67     6
# 92     6
# 111    6
# 172    6
# 149    5
#       ..
# 182    6
# 156    6
# 59     6
# 212    6
# 170    6
# Name: time, Length: 244, dtype: int64

# %%
a = "                  darpan baddest of all          "
a.lstrip()
# Out:
# 'darpan baddest of all          '

# %%
tips["sex"].str.find("ale")
# Out:
# 67     3
# 92     3
# 111    3
# 172    1
# 149    1
#       ..
# 182    1
# 156    1
# 59     1
# 212    1
# 170    1
# Name: sex, Length: 244, dtype: int64

# %%
a="Male"
a.find("ale")
# Out:
# 1

# %%
tips["sex"].str[0:1]
# Out:
# 67     F
# 92     F
# 111    F
# 172    M
# 149    M
#       ..
# 182    M
# 156    M
# 59     M
# 212    M
# 170    M
# Name: sex, Length: 244, dtype: object

# %%
firstlast = pd.DataFrame({"String": ["John Smith", "Jane Cook"]})

firstlast["First_Name"] = firstlast["String"].str.split(" ", expand=True)[0]

firstlast["Last_Name"] = firstlast["String"].str.rsplit(" ", expand=True)[1]

firstlast
# Out:
#        String First_Name Last_Name
# 0  John Smith       John     Smith
# 1   Jane Cook       Jane      Cook

# %%
firstlast["upper"] = firstlast["First_Name"].str.upper()

firstlast["lower"] = firstlast["Last_Name"].str.lower()

#firstlast["title"] = firstlast["string"].str.title()

# %%
firstlast
# Out:
#        String First_Name Last_Name upper  lower
# 0  John Smith       John     Smith  JOHN  smith
# 1   Jane Cook       Jane      Cook  JANE   cook

# %%
df1 = pd.DataFrame({"key": ["A", "B", "C", "D"], "value": np.random.randn(4)})

# %%
df1
# Out:
#   key     value
# 0   A  0.014779
# 1   B -0.123009
# 2   C  2.026917
# 3   D -0.100697

# %%
df2 = pd.DataFrame({"key": ["B", "D", "D", "E"], "value": np.random.randn(4)})

# %%
df2
# Out:
#   key     value
# 0   B -0.167145
# 1   D  0.625690
# 2   D  0.183807
# 3   E  0.026592

# %%
inner_join = df1.merge(df2, on=["key"], how="inner")

# %%
inner_join
# Out:
#   key   value_x   value_y
# 0   B -0.123009 -0.167145
# 1   D -0.100697  0.625690
# 2   D -0.100697  0.183807

# %%
left_join = df1.merge(df2, on=["key"], how="left")
left_join
# Out:
#   key   value_x   value_y
# 0   A  0.014779       NaN
# 1   B -0.123009 -0.167145
# 2   C  2.026917       NaN
# 3   D -0.100697  0.625690
# 4   D -0.100697  0.183807

# %%
right_join = df1.merge(df2, on=["key"], how="right")
right_join
# Out:
#   key   value_x   value_y
# 0   B -0.123009 -0.167145
# 1   D -0.100697  0.625690
# 2   D -0.100697  0.183807
# 3   E       NaN  0.026592

# %%
tips.drop_duplicates().head()
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_bill  new_size  \
# 67         1.07  1.00  Female    Yes   Sat  Dinner     1     0.535         2
# 92         3.75  1.00  Female    Yes   Fri  Dinner     2     1.875         4
# 111        5.25  1.00  Female     No   Sat  Dinner     1     2.625         2
# 172        5.25  5.15    Male    Yes   Sun  Dinner     2     2.625         4
# 149        5.51  2.00    Male     No  Thur   Lunch     2     2.755         4
#
#     bucket      date1      date2  date2_year    months_between
# 67     low 2013-01-15 2015-02-15        2015  <25 * MonthEnds>
# 92     low 2013-01-15 2015-02-15        2015  <25 * MonthEnds>
# 111    low 2013-01-15 2015-02-15        2015  <25 * MonthEnds>
# 172    low 2013-01-15 2015-02-15        2015  <25 * MonthEnds>
# 149    low 2013-01-15 2015-02-15        2015  <25 * MonthEnds>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'new_bill',
#        'new_size', 'bucket', 'date1', 'date2', 'date2_year', 'months_between'],
#       dtype='object')

# %%
pd.pivot_table(
    tips, values="tip", index=["size"], columns=["sex"], aggfunc=np.average
)
# Out:
# sex     Female      Male
# size
# 1     1.276667  1.920000
# 2     2.528448  2.614184
# 3     3.250000  3.476667
# 4     4.021111  4.172143
# 5     5.140000  3.750000
# 6     4.600000  5.850000

# %%
tips == "Sun"
# Out:
#      total_bill    tip    sex  smoker    day   time   size  new_bill  \
# 67        False  False  False   False  False  False  False     False
# 92        False  False  False   False  False  False  False     False
# 111       False  False  False   False  False  False  False     False
# 172       False  False  False   False   True  False  False     False
# 149       False  False  False   False  False  False  False     False
# ..          ...    ...    ...     ...    ...    ...    ...       ...
# 182       False  False  False   False   True  False  False     False
# 156       False  False  False   False   True  False  False     False
# 59        False  False  False   False  False  False  False     False
# 212       False  False  False   False  False  False  False     False
# 170       False  False  False   False  False  False  False     False
#
#      new_size  bucket  date1  date2  date2_year  months_between
# 67      False   False  False  False       False           False
# ...

# %%
tips["day"].str.contains("S")
# Out:
# 67      True
# 92     False
# 111     True
# 172     True
# 149    False
#        ...
# 182     True
# 156     True
# 59      True
# 212     True
# 170     True
# Name: day, Length: 244, dtype: bool

# %%
tips.replace("Thu", "Thursday")
# Out:
#      total_bill    tip     sex smoker   day    time  size  new_bill  new_size  \
# 67         1.07   1.00  Female    Yes   Sat  Dinner     1     0.535         2
# 92         3.75   1.00  Female    Yes   Fri  Dinner     2     1.875         4
# 111        5.25   1.00  Female     No   Sat  Dinner     1     2.625         2
# 172        5.25   5.15    Male    Yes   Sun  Dinner     2     2.625         4
# 149        5.51   2.00    Male     No  Thur   Lunch     2     2.755         4
# ..          ...    ...     ...    ...   ...     ...   ...       ...       ...
# 182       43.35   3.50    Male    Yes   Sun  Dinner     3    21.675         6
# 156       46.17   5.00    Male     No   Sun  Dinner     6    23.085        12
# 59        46.27   6.73    Male     No   Sat  Dinner     4    23.135         8
# 212       46.33   9.00    Male     No   Sat  Dinner     4    23.165         8
# 170       48.81  10.00    Male    Yes   Sat  Dinner     3    24.405         6
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df3 = pd.DataFrame(np.random.randn(1000,2),columns=["B", "C"]).cumsum()
df3["A"] = pd.Series(list(range(len(df3))))
df3.plot(x="A", y="B");

# %%
plt.figure();
figsize=(2,2)
df3.iloc[5].plot(kind="bar");
